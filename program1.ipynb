# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonathandelao10/project1/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first Python program on Colab: Plotting the sine wave

# %% [markdown]
# Import the required packages

# %%
import numpy as np 
import matplotlib.pyplot as plot

# %% [markdown]
# Setting x-axis and y-axis(amplitud)

# %%
time = np.arange(0,10,0.1);
amplitude = np.sin(time)

# %% [markdown]
# # Plot a sine wave using time and amplitude obtained for the sine wave

# %%
plot.plot(time, amplitude)
plot.title('Sine wave')
plot.xlabel('Time')
plot.ylabel('Amplitude = sin(Time)')
plot.grid(True, which='both')
plot.axhline(y=0, color='b')
plot.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p> This is an example of the "Paragraph" markdown.

# %% [markdown]
# <H1> This is an example of the H1 markdown.

# %% [markdown]
# This is an example of a list:
#
# <ol>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ol>

# %% [markdown]
# My favorite social media is [Instagram](https://www.instagram.com/).

# %% [markdown]
# [![A Tennis ball](/assets/images/tennisball.jpg)](https://www.google.com/search?q=tennis+ball+jpg&tbm=isch&ved=2ahUKEwjKq_36tbn1AhXSXs0KHf_MDOIQ2-cCegQIABAA&oq=tennis+ball+jpg&gs_lcp=CgNpbWcQAzIECAAQEzoICAAQCBAeEBNQAFjjA2CiBWgAcAB4AIABd4gB9AKSAQMyLjKYAQCgAQGqAQtnd3Mtd2l6LWltZ8ABAQ&sclient=img&ei=MrblYcrKK9K9tQb_mbOQDg&rlz=1C1YQLS_enSV881SV881#imgrc=WYm__UcMi5wr5M)

# %% [markdown]
# Example of table:
#
#
# | Name      | Age | ID number     |
# | :---        |    :----:   |          ---: |
# | Jonathan      | 20       | 18284728  |
# | David   | 23        | 37348383      |

# %% [markdown]
# Example of emoji:
#
# Gone camping! 😀 Be back soon.

# %% [markdown]
# This is an example of <mark>highlighting</mark>.

# %% [markdown]
# This is an example of strikethrough:
#
# ~~The world is flat.~~

# %% [markdown]
# > This is an example of blockquote.
